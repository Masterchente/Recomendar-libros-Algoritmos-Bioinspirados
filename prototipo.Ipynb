# %% [markdown]
# CLASIFICADOR

# %%
import pandas as pd
from tkinter import Tk, filedialog

# Función para seleccionar archivos
def seleccionar_archivo():
    root = Tk()
    root.withdraw()  # Oculta la ventana de Tkinter
    archivo = filedialog.askopenfilename(title="Selecciona un archivo CSV", filetypes=[("Archivos CSV", "*.csv")])
    return archivo

# Cargar bases de datos
print("Selecciona la base de datos de libros:")
archivo_libros = seleccionar_archivo()
print("Selecciona el historial de usuario:")
archivo_historial = seleccionar_archivo()

df_libros = pd.read_csv(archivo_libros, quotechar='"', on_bad_lines='skip')
df_historial = pd.read_csv(archivo_historial)

# Limpieza de columnas
df_libros.columns = df_libros.columns.str.strip()
df_libros.columns = df_libros.columns.str.replace('  ', ' ')

# Filtrar libros que están en el historial
libros_historial = df_libros[df_libros["bookID"].isin(df_historial["bookID"])].copy()

# Excluir libros que están en el historial de las recomendaciones
recomendaciones = df_libros[~df_libros["bookID"].isin(libros_historial["bookID"])]

# Filtrar por idioma del historial
idiomas_historial = libros_historial['language_code'].unique()
print(f"Idiomas en el historial del usuario: {idiomas_historial}")
recomendaciones = recomendaciones[recomendaciones['language_code'].isin(idiomas_historial)]

# Priorizar idiomas más leídos
def priorizar_idiomas(df, idiomas_frecuencia):
    df = df.copy()  # Crear una copia explícita del DataFrame
    df.loc[:, 'idioma_score'] = df['language_code'].map(idiomas_frecuencia)
    return df.sort_values(by=['idioma_score', 'average_rating'], ascending=[False, False])

# Crear frecuencia de idiomas
idiomas_frecuencia = libros_historial['language_code'].value_counts(normalize=True).to_dict()
recomendaciones = priorizar_idiomas(recomendaciones, idiomas_frecuencia)

# Relajar el filtro por promedio de páginas
promedio_paginas = libros_historial['num_pages'].mean()
desviacion_paginas = libros_historial['num_pages'].std()
recomendaciones = recomendaciones[
    (recomendaciones['num_pages'] >= promedio_paginas - (2 * desviacion_paginas)) & 
    (recomendaciones['num_pages'] <= promedio_paginas + (2 * desviacion_paginas))
]

# Relajar el filtro por reseñas
recomendaciones = recomendaciones[
    (recomendaciones['average_rating'] >= 3.0) & 
    (recomendaciones['ratings_count'] > 10)
]

# Asegurar representación de todos los idiomas del historial
def balancear_idiomas(df, idiomas_historial, min_por_idioma=5):
    df_balanceado = pd.DataFrame()
    for idioma in idiomas_historial:
        subset = df[df['language_code'] == idioma]
        if len(subset) < min_por_idioma:
            df_balanceado = pd.concat([df_balanceado, subset])
        else:
            df_balanceado = pd.concat([df_balanceado, subset.head(min_por_idioma)])
    return df_balanceado

recomendaciones = balancear_idiomas(recomendaciones, idiomas_historial)

# Ajustar el umbral para obtener entre 50 y 100 recomendaciones
while len(recomendaciones) > 100:
    recomendaciones = recomendaciones.sample(frac=0.9, random_state=42)
if len(recomendaciones) < 50:
    print("Aumentando el umbral para obtener más recomendaciones...")
    adicionales = df_libros[
        (df_libros['average_rating'] >= 2.5) & 
        (df_libros['ratings_count'] > 5) & 
        (~df_libros['bookID'].isin(recomendaciones['bookID'])) & 
        (df_libros['language_code'].isin(idiomas_historial))
    ]
    adicionales = priorizar_idiomas(adicionales, idiomas_frecuencia)
    recomendaciones = pd.concat([recomendaciones, adicionales]).drop_duplicates()
    recomendaciones = recomendaciones.head(100)

# Verificar que ningún libro en las recomendaciones esté en el historial
recomendaciones = recomendaciones[~recomendaciones["bookID"].isin(libros_historial["bookID"])]

# Guardar la base de datos de recomendaciones finales
nombre_archivo = "recomendaciones_finales.csv"
recomendaciones.to_csv(nombre_archivo, index=False)
print(f"\nBase de datos de recomendaciones finales guardada como '{nombre_archivo}'.")

# Mostrar un resumen de las recomendaciones
print("\nResumen de las recomendaciones finales:")
print(recomendaciones[["title", "authors", "average_rating", "num_pages", "ratings_count", "language_code"]].head(50))
# Out:
# Selecciona la base de datos de libros:
# Selecciona el historial de usuario:
# Idiomas en el historial del usuario: ['eng' 'en-US' 'spa']
# Aumentando el umbral para obtener más recomendaciones...
#
# Base de datos de recomendaciones finales guardada como 'recomendaciones_finales.csv'.
#
# Resumen de las recomendaciones finales:
#                                                    title  \
# 4373                              Existential Meditation
# 6587                      The Complete Calvin and Hobbes
# 6589       It's a Magical World (Calvin and Hobbes  #11)
# 1848                                         Early Color
# 6590   Homicidal Psycho Jungle Cat (Calvin and Hobbes...
# 4811            The Feynman Lectures on Physics Vols 7-8
# 4810            The Feynman Lectures on Physics Vols 3-4
# 7042   The Sibley Field Guide to Birds of Western Nor...
# 6196   Discovery of the Presence of God: Devotional N...
# 1611             The Feynman Lectures on Physics  3 Vols
# 11295                  Tenetur nisi error veritatis quod
# 11533          Occaecati quasi impedit nam sapiente modi
# 11594              Architecto odit dignissimos quibusdam
# 11886                       Tempore quo magni temporibus
# 11381           Provident vel praesentium voluptas nihil
# 9812                                            Corvette
# 4697   True Harvest: Readings From Henry David Thorea...
# 9133   The Beatles' Story on Capitol Records  Part Tw...
# 6593   Calvin and Hobbes: Sunday Pages 1985-1995: An ...
# 306    The 5 Love Languages / The 5 Love Languages Jo...
# 5614                                    Study Bible: NIV
# 6497      The Complete Aubrey/Maturin Novels (5 Volumes)
# 10937  The Price of the Ticket: Collected Nonfiction ...
# 6591                            The Days Are Just Packed
# 8183   A Wife After God's Own Heart Growth and Study ...
# 8362   Cook's Illustrated 2003 (Cook's Illustrated An...
# 1530                The Life and Times of Scrooge McDuck
# 8034   Restless Till We Rest in You: 60 Reflections f...
# 9785   Getting a Grip on the Basics: Building a Firm ...
# 6294                    The Absolute Sandman  Volume One
# 1056   The New Annotated Sherlock Holmes: The Complet...
# 6257              The J.R.R. Tolkien Companion and Guide
# 7103                        The Gospel According to Luke
# 9862       The Shawshank Redemption: The Shooting Script
# 807    Novels 1901–1902: The Sacred Fount / The Wings...
# 3657       The Collected Autobiographies of Maya Angelou
# 4813               The Feynman Lectures on Physics Vol 3
# 6588        The Calvin and Hobbes Tenth Anniversary Book
# 6592      The Calvin And Hobbes:  Tenth Anniversary Book
# 551             Dionysiac Poetics and Euripides' Bacchae
# 3071                            Herbert the Timid Dragon
# 5348   The World of Peter Rabbit (Original Peter Rabb...
# 6288   Nausicaä of the Valley of the Wind  Vol. 6 (Na...
# 9015               The Feynman Lectures on Physics Vol 2
# 9079           Lego Star Wars: Prima Official Game Guide
# 145                               100 Years of Lynchings
# 4763   Collected Essays: Notes of a Native Son / Nobo...
# 4831          The Complete C.S. Lewis Signature Classics
# 5392          A Guide to the Words of My Perfect Teacher
# 6289   Nausicaä of the Valley of the Wind  Vol. 5 (Na...
#
#                                                  authors  average_rating  \
# 4373                                     Simon Cleveland            4.91
# 6587                                      Bill Watterson            4.82
# 6589                                      Bill Watterson            4.76
# 1848                         Saul Leiter/Martin Harrison            4.73
# 6590                                      Bill Watterson            4.72
# 4811                                  Richard P. Feynman            4.80
# 4810                                  Richard P. Feynman            4.71
# 7042                                  David Allen Sibley            4.69
# 6196                                    David R. Hawkins            4.61
# 1611   Richard P. Feynman/Robert B. Leighton/Matthew ...            4.60
# 11295                               Severiano del Osorio            5.00
# 11533                             Mercedes Bonet Atienza            5.00
# 11594                           Florinda Casares Guillén            5.00
# 11886                         Jose Luis Alcalde Carreras            5.00
# 11381                               Nereida Bou Expósito            4.99
# 9812                                        Jerry Burton            4.83
# 4697                Henry David Thoreau/Barry M. Andrews            4.75
# 9133                                        Bruce Spizer            4.72
# 6593                                      Bill Watterson            4.71
# 306                                         Gary Chapman            4.70
# 5614                                           Anonymous            4.70
# 6497                                     Patrick O'Brian            4.70
# 10937                                      James Baldwin            4.70
# 6591                                      Bill Watterson            4.69
# 8183                                    Elizabeth George            4.69
# 8362                         Cook's Illustrated Magazine            4.69
# 1530                                            Don Rosa            4.67
# 8034                                  Augustine of Hippo            4.67
# 9785                                       Beth A. Jones            4.67
# 6294   Neil Gaiman/Mike Dringenberg/Chris Bachalo/Mic...            4.65
# 1056                Arthur Conan Doyle/Leslie S. Klinger            4.64
# 6257                    Christina Scull/Wayne G. Hammond            4.64
# 7103                             Anonymous/Thomas Cahill            4.64
# 9862                         Frank Darabont/Stephen King            4.64
# 807                              Henry James/Leo Bersani            4.63
# 3657                                        Maya Angelou            4.63
# 4813   Richard P. Feynman/Robert B. Leighton/Matthew ...            4.63
# 6588                                      Bill Watterson            4.63
# 6592                                      Bill Watterson            4.63
# 551                                        Charles Segal            4.62
# 3071                                        Mercer Mayer            4.62
# 5348                                      Beatrix Potter            4.62
# 6288   Hayao Miyazaki/Matt Thorn/Kaori Inoue/Joe Yama...            4.62
# 9015   Richard P. Feynman/Robert B. Leighton/Matthew ...            4.62
# 9079                                 Michael Littlefield            4.62
# 145                                       Ralph Ginzburg            4.61
# 4763                         James Baldwin/Toni Morrison            4.61
# 4831                                          C.S. Lewis            4.61
# 5392   Ngawang Pelzang/Padmakara Translation Group/Pa...            4.61
# 6289   Hayao Miyazaki/Matt Thorn/Kaori Inoue/Joe Yama...            4.61
#
#        num_pages  ratings_count language_code
# 4373         100             11           eng
# 6587        1456          32213           eng
# 6589         176          23875           eng
# 1848         156            144           eng
# 6590         176          15365           eng
# 4811           0             20         en-US
# 4810           0             21         en-US
# 7042         473            730         en-US
# 6196         296            186         en-US
# 1611           3             78         en-US
# 11295        937           1511           spa
# 11533        972           2763           spa
# 11594        315           4404           spa
# 11886        212           4622           spa
# 11381        924           7157           spa
# 9812         320              6           eng
# 4697         304              8           eng
# 9133         264             29           eng
# 6593          96           3613           eng
# 306            0             22           eng
# 5614        2198           4166           eng
# 6497        6576           1338           eng
# 10937        712            404           eng
# 6591         176          20308           eng
# 8183         160              9           eng
# 8362         212             26           eng
# 1530         266           2467           eng
# 8034         158              6           eng
# 9785         124              9           eng
# 6294         612          15640           eng
# 1056        1878           1411           eng
# 6257        2264             45           eng
# 7103          81            169           eng
# 9862         184           2406           eng
# 807          713             27           eng
# 3657        1184            991           eng
# 4813         384            716           eng
# 6588         208          49122           eng
# 6592         208            303           eng
# 551          440             12           eng
# 3071          48             23           eng
# 5348        1072            220           eng
# 6288         159           1776           eng
# 9015         512             17           eng
# 9079         128             27           eng
# 145          270             88           eng
# 4763         869           1495           eng
# 4831         746            925           eng
# 5392         336             79           eng
# 6289         151           1904           eng

# %% [markdown]
# ALGORITMO GENETICO

# %%
import pandas as pd
import csv
from collections import defaultdict
import random

def calcular_puntuaciones(historial_path):
    author_count = defaultdict(int)
    language_count = defaultdict(int)

    with open(historial_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            authors = row['authors'].split('/')
            for author in authors:
                author_count[author.strip()] += 1
            language_count[row['language_code'].strip()] += 1

    max_author_count = max(author_count.values())
    max_language_count = max(language_count.values())

    author_scores = {author: (count / max_author_count) * 10 for author, count in author_count.items()}
    language_scores = {language: (count / max_language_count) * 10 for language, count in language_count.items()}

    return author_scores, language_scores

def inicializacion_random_poblacion(recomendaciones, n, subset_size):
    poblacion = []
    for _ in range(n):
        subset = recomendaciones.sample(n=subset_size, replace=False).to_dict(orient='records')
        poblacion.append(subset)
    return poblacion

def calcular_aptitud(subset, author_scores, language_scores):
    avg_rating = sum([libro['average_rating'] for libro in subset]) / len(subset)
    author_score = sum([author_scores.get(libro['authors'].split('/')[0].strip(), 0) for libro in subset]) / len(subset)
    language_score = sum([language_scores.get(libro['language_code'], 0) for libro in subset]) / len(subset)
    return 0.9 * avg_rating + 5 * author_score + 1.5 * language_score

def seleccion_ruleta(poblacion, aptitudes):
    total_aptitud = sum(aptitudes)
    seleccionados = []
    while len(seleccionados) < len(poblacion):
        pick = random.uniform(0, total_aptitud)
        acumulado = 0
        for i, aptitud in enumerate(aptitudes):
            acumulado += aptitud
            if acumulado >= pick:
                seleccionados.append(poblacion[i])
                break
    if len(seleccionados) % 2 != 0:
        seleccionados.pop()
    return seleccionados

def cruzar_padres(padre1, padre2):
    punto_cruce = random.randint(1, len(padre1) - 1)
    hijo1 = padre1[:punto_cruce] + padre2[punto_cruce:]
    hijo2 = padre2[:punto_cruce] + padre1[punto_cruce:]
    return hijo1, hijo2


def mutar(hijo, recomendaciones, libros_historial):
    if random.uniform(0, 1) <= 0.1:  
        indice = random.randint(0, len(hijo) - 1)
        titulos_usados = {libro['title'] for libro in hijo}
        titulos_usados.update(libros_historial['title'].tolist())
        
        nuevo_libro = recomendaciones.sample(n=1).to_dict(orient='records')[0]
        while nuevo_libro['title'] in titulos_usados:
            nuevo_libro = recomendaciones.sample(n=1).to_dict(orient='records')[0]
        
        hijo[indice] = nuevo_libro  
    return hijo


def completar_subconjunto(subset, recomendaciones, libros_historial, subset_size):
   
    titulos_usados = {libro['title'] for libro in subset}
    titulos_usados.update(libros_historial['title'].tolist())
    
    while len(subset) < subset_size:
        nuevo_libro = recomendaciones.sample(n=1).to_dict(orient='records')[0]
        if nuevo_libro['title'] not in titulos_usados:
            subset.append(nuevo_libro)
            titulos_usados.add(nuevo_libro['title']) 
    return subset

def algoritmo_genetico(recomendaciones, author_scores, language_scores, libros_historial, generaciones=50, poblacion_size=10, subset_size=5):
    poblacion = inicializacion_random_poblacion(recomendaciones, poblacion_size, subset_size)
    
    for gen in range(generaciones):
        print(f"\nGeneración {gen + 1}:")
        
        for i, subset in enumerate(poblacion):
            print(f"Individuo {i + 1}: {[libro['title'] for libro in subset]}")
        
        aptitudes = [calcular_aptitud(subset, author_scores, language_scores) for subset in poblacion]
        print(f"Aptitudes: {aptitudes}")
        
        padres = seleccion_ruleta(poblacion, aptitudes)

        nueva_generacion = []
        for i in range(0, len(padres) - 1, 2):
            ran = random.uniform(0, 1)
            if ran <= 0.85:
                hijo1, hijo2 = cruzar_padres(padres[i], padres[i+1])
                hijo1 = mutar(hijo1, recomendaciones, libros_historial)
                hijo2 = mutar(hijo2, recomendaciones, libros_historial)
            else:
                hijo1 = padres[i]
                hijo2 = padres[i+1]

            hijo1 = completar_subconjunto(hijo1, recomendaciones, libros_historial, subset_size)
            hijo2 = completar_subconjunto(hijo2, recomendaciones, libros_historial, subset_size)

            nueva_generacion.extend([hijo1, hijo2])
        
        poblacion = nueva_generacion
    
    aptitudes_finales = [calcular_aptitud(subset, author_scores, language_scores) for subset in poblacion]
    mejor_solucion = poblacion[aptitudes_finales.index(max(aptitudes_finales))]
    return mejor_solucion

historial_path = 'historial_usuario.csv'
recomendaciones_path = 'recomendaciones_finales.csv'

recomendaciones = pd.read_csv(recomendaciones_path)
libros_historial = pd.read_csv(historial_path)

author_scores, language_scores = calcular_puntuaciones(historial_path)

try:
    mejor_subconjunto = algoritmo_genetico(recomendaciones, author_scores, language_scores, libros_historial, generaciones=50, poblacion_size=10, subset_size=5)
    print("\nMejor subconjunto de libros recomendado:")
    for libro in mejor_subconjunto:
        print(libro)
except ValueError as e:
    print(f"Error en el algoritmo genético: {e}")
# Out:
# Generación 1:
# Individuo 1: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['The Complete Calvin and Hobbes', 'A Guide to the Words of My Perfect Teacher', 'The Lord of the Rings: The Art of the Fellowship of the Ring', 'The Absolute Sandman  Volume One', 'Occaecati quasi impedit nam sapiente modi']
# Individuo 3: ['Tempore quo magni temporibus', 'Fullmetal Alchemist  Vol. 14 (Fullmetal Alchemist  #14)', 'The Sawtooth Wolves', 'Getting a Grip on the Basics: Building a Firm Foundation for the Victorious Christian Life', 'The Feynman Lectures on Physics Vol 3']
# Individuo 4: ['Provident vel praesentium voluptas nihil', 'Harry Potter and the Half-Blood Prince (Harry Potter  #6)', 'Fullmetal Alchemist  Vol. 6 (Fullmetal Alchemist  #6)', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 5 (Nausicaä of the Valley of the Wind  #5)']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'Study Bible: NIV', 'The New Annotated Sherlock Holmes: The Complete Short Stories', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 6: ['The Feynman Lectures on Physics Vols 7-8', 'Dostoevsky: The Mantle of the Prophet  1871-1881', "The Beatles' Story on Capitol Records  Part Two: The Albums", 'Nausicaä of the Valley of the Wind  Vol. 7 (Nausicaä of the Valley of the Wind  #7)', 'Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)']
# Individuo 7: ['Fullmetal Alchemist  Vol. 4 (Fullmetal Alchemist  #4)', 'The Complete Novels', 'The Complete Maus', 'Herbert the Timid Dragon', 'Fullmetal Alchemist: The Abducted Alchemist (Fullmetal Alchemist  #2)']
# Individuo 8: ['The Sibley Field Guide to Birds of Western North America', 'The Price of the Ticket: Collected Nonfiction  1948-1985', 'Coffin: The Art of Vampire Hunter D', 'Fullmetal Alchemist  Vol. 12 (Fullmetal Alchemist  #12)', 'The Complete Maus']
# Individuo 9: ['Vinyl Cafe Odd Jobs', 'Fullmetal Alchemist  Vol. 4 (Fullmetal Alchemist  #4)', 'Herbert the Timid Dragon', "Marine Conservation Biology: The Science of Maintaining the Sea's Biodiversity", 'The Collected Autobiographies of Maya Angelou']
# Individuo 10: ['The Complete C.S. Lewis Signature Classics', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Marine Conservation Biology: The Science of Maintaining the Sea's Biodiversity", 'Architecto odit dignissimos quibusdam']
# Aptitudes: [13.563333333333334, 16.37171111111111, 16.33571111111111, 22.971777777777778, 19.158, 23.073888888888888, 19.1112, 16.383822222222225, 19.131, 13.539933333333334]
#
# Generación 2:
# Individuo 1: ['The Complete C.S. Lewis Signature Classics', 'Study Bible: NIV', 'The New Annotated Sherlock Holmes: The Complete Short Stories', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 2: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Marine Conservation Biology: The Science of Maintaining the Sea's Biodiversity", 'Architecto odit dignissimos quibusdam']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'Study Bible: NIV', "The Beatles' Story on Capitol Records  Part Two: The Albums", 'Nausicaä of the Valley of the Wind  Vol. 7 (Nausicaä of the Valley of the Wind  #7)', 'Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)']
# Individuo 4: ['The Feynman Lectures on Physics Vols 7-8', 'Dostoevsky: The Mantle of the Prophet  1871-1881', 'The New Annotated Sherlock Holmes: The Complete Short Stories', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 5: ['The Sibley Field Guide to Birds of Western North America', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['The Shawshank Redemption: The Shooting Script', 'The Price of the Ticket: Collected Nonfiction  1948-1985', 'Coffin: The Art of Vampire Hunter D', 'Fullmetal Alchemist  Vol. 12 (Fullmetal Alchemist  #12)', 'The Complete Maus']
# Individuo 7: ['The Complete C.S. Lewis Signature Classics', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Marine Conservation Biology: The Science of Maintaining the Sea's Biodiversity", 'Architecto odit dignissimos quibusdam']
# Individuo 8: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['The Complete Calvin and Hobbes', 'A Guide to the Words of My Perfect Teacher', 'The Lord of the Rings: The Art of the Fellowship of the Ring', 'Occaecati quasi impedit nam sapiente modi', 'Dostoevsky: The Mantle of the Prophet  1871-1881']
# Individuo 10: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'The Absolute Sandman  Volume One', 'Occaecati quasi impedit nam sapiente modi']
# Aptitudes: [19.1634, 13.534533333333334, 25.837266666666665, 16.394622222222225, 10.794555555555554, 19.1526, 13.539933333333334, 13.563333333333334, 16.35551111111111, 13.579533333333334]
#
# Generación 3:
# Individuo 1: ['The Complete C.S. Lewis Signature Classics', 'Study Bible: NIV', 'The New Annotated Sherlock Holmes: The Complete Short Stories', 'Occaecati quasi impedit nam sapiente modi', 'Dostoevsky: The Mantle of the Prophet  1871-1881']
# Individuo 2: ['The Complete Calvin and Hobbes', 'A Guide to the Words of My Perfect Teacher', 'The Lord of the Rings: The Art of the Fellowship of the Ring', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Marine Conservation Biology: The Science of Maintaining the Sea's Biodiversity", 'Architecto odit dignissimos quibusdam']
# Individuo 5: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 7: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 8: ['The Feynman Lectures on Physics Vols 7-8', 'Dostoevsky: The Mantle of the Prophet  1871-1881', 'The New Annotated Sherlock Holmes: The Complete Short Stories', "Marine Conservation Biology: The Science of Maintaining the Sea's Biodiversity", 'Architecto odit dignissimos quibusdam']
# Individuo 9: ['The Feynman Lectures on Physics Vols 7-8', 'Dostoevsky: The Mantle of the Prophet  1871-1881', 'The New Annotated Sherlock Holmes: The Complete Short Stories', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 10: ['The Complete C.S. Lewis Signature Classics', 'Study Bible: NIV', 'The New Annotated Sherlock Holmes: The Complete Short Stories', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Aptitudes: [16.34291111111111, 19.176000000000002, 13.536333333333335, 13.561533333333333, 13.563333333333334, 13.563333333333334, 16.349622222222223, 13.579533333333334, 16.394622222222225, 19.1634]
#
# Generación 4:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 2: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 5: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 7: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 9: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [16.349622222222223, 16.349622222222223, 16.337022222222224, 13.548933333333334, 16.376622222222224, 13.536333333333335, 13.563333333333334, 16.349622222222223, 13.575933333333335, 16.337022222222224]
#
# Generación 5:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 3: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['The Shawshank Redemption: The Shooting Script', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 7: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 9: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Aptitudes: [16.337022222222224, 13.575933333333335, 16.376622222222224, 16.349622222222223, 13.552533333333335, 13.547133333333335, 16.376622222222224, 16.349622222222223, 13.548933333333334, 13.548933333333334]
#
# Generación 6:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'Early Color', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 7: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['The Shawshank Redemption: The Shooting Script', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [13.552533333333335, 16.376622222222224, 19.1508, 13.548933333333334, 13.552533333333335, 13.552533333333335, 16.349622222222223, 16.337022222222224, 16.360422222222223, 13.536333333333335]
#
# Generación 7:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 4: ['The Shawshank Redemption: The Shooting Script', 'The Sibley Field Guide to Birds of Western North America', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 7: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'Early Color', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Aptitudes: [13.536333333333335, 13.552533333333335, 13.565133333333334, 16.364022222222225, 16.337022222222224, 13.552533333333335, 13.552533333333335, 13.536333333333335, 19.1508, 13.548933333333334]
#
# Generación 8:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 7: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [16.337022222222224, 13.536333333333335, 16.337022222222224, 13.536333333333335, 13.552533333333335, 13.565133333333334, 13.548933333333334, 13.536333333333335, 13.552533333333335, 13.536333333333335]
#
# Generación 9:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', 'Fullmetal Alchemist  Vol. 9 (Fullmetal Alchemist  #9)', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 7: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [13.536333333333335, 13.552533333333335, 16.337022222222224, 13.565133333333334, 13.557933333333335, 13.552533333333335, 16.337022222222224, 13.536333333333335, 13.536333333333335, 13.536333333333335]
#
# Generación 10:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', 'Fullmetal Alchemist  Vol. 9 (Fullmetal Alchemist  #9)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 7: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [16.337022222222224, 13.552533333333335, 13.552533333333335, 13.536333333333335, 16.35322222222222, 13.541733333333333, 13.536333333333335, 16.337022222222224, 16.337022222222224, 16.337022222222224]
#
# Generación 11:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Sibley Field Guide to Birds of Western North America', 'Fullmetal Alchemist  Vol. 9 (Fullmetal Alchemist  #9)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 7: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Restless Till We Rest in You: 60 Reflections from the Writings of St. Augustine (Saints Speak Today)']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The J.R.R. Tolkien Companion and Guide', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Aptitudes: [16.337022222222224, 16.35322222222222, 13.541733333333333, 16.337022222222224, 16.337022222222224, 16.337022222222224, 16.356822222222224, 16.337022222222224, 16.31411111111111, 13.548933333333334]
#
# Generación 12:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', '100 Years of Lynchings', 'Occaecati quasi impedit nam sapiente modi', 'The Calvin and Hobbes Tenth Anniversary Book']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Restless Till We Rest in You: 60 Reflections from the Writings of St. Augustine (Saints Speak Today)']
# Individuo 7: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The J.R.R. Tolkien Companion and Guide', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'Occaecati quasi impedit nam sapiente modi', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [16.337022222222224, 16.337022222222224, 16.337022222222224, 13.548933333333334, 16.337022222222224, 16.356822222222224, 16.337022222222224, 16.337022222222224, 16.31411111111111, 16.337022222222224]
#
# Generación 13:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['Discovery of the Presence of God: Devotional Nonduality', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Restless Till We Rest in You: 60 Reflections from the Writings of St. Augustine (Saints Speak Today)']
# Individuo 7: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [16.337022222222224, 16.337022222222224, 16.337022222222224, 16.337022222222224, 16.337022222222224, 13.584444444444443, 16.337022222222224, 16.337022222222224, 16.337022222222224, 16.337022222222224]
#
# Generación 14:
# Individuo 1: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Cook's Illustrated 2005 (Cook's Illustrated Annuals)", 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 5: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Sawtooth Wolves']
# Individuo 7: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Come Away My Beloved']
# Aptitudes: [16.340622222222223, 16.337022222222224, 16.337022222222224, 16.337022222222224, 16.337022222222224, 16.340622222222223, 16.337022222222224, 16.337022222222224, 16.337022222222224, 16.340622222222223]
#
# Generación 15:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'The Sawtooth Wolves']
# Individuo 7: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Cook's Illustrated 2005 (Cook's Illustrated Annuals)", 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [16.337022222222224, 16.337022222222224, 16.337022222222224, 16.337022222222224, 16.337022222222224, 20.788666666666668, 16.337022222222224, 16.337022222222224, 16.337022222222224, 16.340622222222223]
#
# Generación 16:
# Individuo 1: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Cook's Illustrated 2005 (Cook's Illustrated Annuals)", 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'The Sawtooth Wolves']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Cook's Illustrated 2005 (Cook's Illustrated Annuals)", 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 7: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'The Feynman Lectures on Physics Vols 7-8']
# Individuo 8: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [16.337022222222224, 16.337022222222224, 16.340622222222223, 20.788666666666668, 16.340622222222223, 16.337022222222224, 13.602444444444444, 16.337022222222224, 16.337022222222224, 16.337022222222224]
#
# Generación 17:
# Individuo 1: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'True Harvest: Readings From Henry David Thoreau For Every Day Of The Year', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'The Sawtooth Wolves']
# Individuo 6: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Cook's Illustrated 2005 (Cook's Illustrated Annuals)", 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 7: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Calvin and Hobbes Tenth Anniversary Book', 'The Sawtooth Wolves']
# Individuo 9: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "In Search of Lost Time  Vol. 2: Within a Budding Grove  Part 2 & The Guermantes' Way", 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [16.369422222222223, 16.337022222222224, 16.337022222222224, 16.337022222222224, 20.788666666666668, 16.340622222222223, 20.785066666666665, 16.355022222222225, 16.337022222222224, 16.340622222222223]
#
# Generación 18:
# Individuo 1: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'True Harvest: Readings From Henry David Thoreau For Every Day Of The Year', 'The Complete Novels', 'The Sawtooth Wolves']
# Individuo 2: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', "Cook's Illustrated 2005 (Cook's Illustrated Annuals)", 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'True Harvest: Readings From Henry David Thoreau For Every Day Of The Year', 'The Complete Novels', 'The Sawtooth Wolves']
# Individuo 7: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'The Sawtooth Wolves']
# Individuo 8: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Calvin and Hobbes Tenth Anniversary Book', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [16.373022222222225, 16.337022222222224, 16.340622222222223, 16.337022222222224, 20.785066666666665, 16.373022222222225, 20.788666666666668, 16.351422222222222, 20.785066666666665, 20.785066666666665]
#
# Generación 19:
# Individuo 1: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 2: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 3: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 4: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'True Harvest: Readings From Henry David Thoreau For Every Day Of The Year', 'The Complete Novels', 'The Sawtooth Wolves']
# Individuo 5: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 6: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'True Harvest: Readings From Henry David Thoreau For Every Day Of The Year', 'The Complete Novels', 'The Sawtooth Wolves']
# Individuo 7: ['Dewdrops on a Lotus Leaf: Zen Poems of Ryokan', 'The Feynman Lectures on Physics  3 Vols', 'Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8)', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 8: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 9: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Individuo 10: ['The Sawtooth Wolves', 'The Feynman Lectures on Physics  3 Vols', 'The Lord of the Rings / The Hobbit', 'The Complete Novels', 'Cocolat: Extraordinary Chocolate Desserts']
# Aptitudes: [20.785066666666665, 20.785066666666665, 20.785066666666665, 16.373022222222225, 20.785066666666665, 16.373022222222225, 16.337022222222224, 20.785066666666665, 20.785066666666665, 20.785066666666665]
#
# Generación 20:
# ...
# Individuo 4: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 5: ["Cook's Illustrated 2003 (Cook's Illustrated Annuals)", 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 6: ["Cook's Illustrated 2003 (Cook's Illustrated Annuals)", 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 7: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 8: ['The Calvin and Hobbes Tenth Anniversary Book', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 9: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 10: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Aptitudes: [23.597044444444442, 23.591644444444444, 23.607844444444446, 23.595244444444447, 23.607844444444446, 23.607844444444446, 23.588044444444446, 23.597044444444442, 23.595244444444447, 23.595244444444447]
#
# Generación 47:
# Individuo 1: ['The Feynman Lectures on Physics Vol 2', 'The Life and Times of Scrooge McDuck', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 2: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 3: ['The Calvin and Hobbes Tenth Anniversary Book', 'Fullmetal Alchemist  Vol. 3 (Fullmetal Alchemist  #3)', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 4: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Discovery of the Presence of God: Devotional Nonduality']
# Individuo 5: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 6: ['The Calvin and Hobbes Tenth Anniversary Book', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 7: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 8: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 9: ['The Feynman Lectures on Physics Vol 2', 'Fullmetal Alchemist  Vol. 3 (Fullmetal Alchemist  #3)', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 10: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Aptitudes: [23.588044444444446, 23.588044444444446, 23.570044444444445, 20.821066666666667, 19.1922, 23.597044444444442, 23.595244444444447, 23.595244444444447, 23.568244444444446, 23.595244444444447]
#
# Generación 48:
# Individuo 1: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 2: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 3: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 4: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 5: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 6: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Discovery of the Presence of God: Devotional Nonduality']
# Individuo 7: ['The Calvin and Hobbes Tenth Anniversary Book', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 8: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 9: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 10: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Aptitudes: [23.588044444444446, 23.588044444444446, 19.1922, 19.1922, 23.595244444444447, 20.821066666666667, 23.597044444444442, 23.588044444444446, 19.185000000000002, 23.595244444444447]
#
# Generación 49:
# Individuo 1: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 2: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 3: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 4: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 5: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 6: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 7: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Discovery of the Presence of God: Devotional Nonduality']
# Individuo 8: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 9: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 10: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Aptitudes: [23.595244444444447, 23.588044444444446, 23.595244444444447, 19.1922, 23.588044444444446, 23.595244444444447, 20.81386666666667, 23.595244444444447, 23.588044444444446, 19.1922]
#
# Generación 50:
# Individuo 1: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 2: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 3: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 4: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Discovery of the Presence of God: Devotional Nonduality']
# Individuo 5: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 6: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 7: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 8: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Complete Calvin and Hobbes', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 9: ['The Feynman Lectures on Physics Vol 2', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)']
# Individuo 10: ['The Sawtooth Wolves', 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'The Lord of the Rings / The Hobbit', 'Jane Austen: The Complete Novels', 'Discovery of the Presence of God: Devotional Nonduality']
# Aptitudes: [23.588044444444446, 19.1922, 23.588044444444446, 20.821066666666667, 19.1922, 19.1922, 23.595244444444447, 19.185000000000002, 23.595244444444447, 20.81386666666667]
#
# Mejor subconjunto de libros recomendado:
# {'bookID': 35111, 'title': 'The Feynman Lectures on Physics Vol 2', 'authors': 'Richard P. Feynman/Robert B. Leighton/Matthew L. Sands', 'average_rating': 4.62, 'isbn': '0805390472', 'isbn13': 9780805390476, 'language_code': 'eng', 'num_pages': 512, 'ratings_count': 17, 'text_reviews_count': 2, 'publication_date': '9/1/2005', 'publisher': 'Pearson Education', 'idioma_score': 0.9}
# {'bookID': 24820, 'title': 'Calvin and Hobbes: Sunday Pages 1985-1995: An Exhibition Catalogue', 'authors': 'Bill Watterson', 'average_rating': 4.71, 'isbn': '0740721356', 'isbn13': 9780740721359, 'language_code': 'eng', 'num_pages': 96, 'ratings_count': 3613, 'text_reviews_count': 85, 'publication_date': '9/17/2001', 'publisher': 'Andrews McMeel Publishing', 'idioma_score': 0.9}
# {'bookID': 15336, 'title': 'The Lord of the Rings / The Hobbit', 'authors': 'J.R.R. Tolkien', 'average_rating': 4.59, 'isbn': '0007144083', 'isbn13': 9780007144082, 'language_code': 'eng', 'num_pages': 1600, 'ratings_count': 141, 'text_reviews_count': 5, 'publication_date': '10/7/2002', 'publisher': 'Collins Modern Classics', 'idioma_score': 0.9}
# {'bookID': 2153, 'title': 'Jane Austen: The Complete Novels', 'authors': 'Jane Austen', 'average_rating': 4.55, 'isbn': '0517118297', 'isbn13': 9780517118290, 'language_code': 'eng', 'num_pages': 1103, 'ratings_count': 267, 'text_reviews_count': 24, 'publication_date': '6/1/1994', 'publisher': 'Gramercy Books', 'idioma_score': 0.9}
# {'bookID': 23720, 'title': 'Nausicaä of the Valley of the Wind  Vol. 4 (Nausicaä of the Valley of the Wind  #4)', 'authors': 'Hayao Miyazaki/David Lewis/Toren Smith/Kaori Inoue/Joe Yamazaki/Walden Wong/Izumi Evers', 'average_rating': 4.59, 'isbn': '1591163528', 'isbn13': 9781591163527, 'language_code': 'eng', 'num_pages': 134, 'ratings_count': 1956, 'text_reviews_count': 38, 'publication_date': '6/2/2004', 'publisher': 'VIZ Media', 'idioma_score': 0.9}
